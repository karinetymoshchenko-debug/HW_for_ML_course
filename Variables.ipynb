# %%
# Variables - print function
name="Karina"
age=39
height=165.7
is_student=True

# %%
print (f"My name is {name}")
# Out:
# My name is Karina

# %%
print(f"I`m {age} years old")
# Out:
# I`m 39 years old

# %%
print(f"I`m not tall, I `m about {height}")
# Out:
# I`m not tall, I `m about 165.7

# %%
# # Variables - calc function
var_1=15
var_2=4

# %%
print(var_1 + var_2)
print(var_1-var_2)
print(var_1*var_2)
print(var_1/var_2)

print(var_1//var_2)
print(var_1%var_2)
print(var_1**var_2)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
last_name="Tymoschenko"

# %%
last_name, name
# Out:
# ('Tymoschenko', 'Karina')

# %%
full_name=name+" "+last_name
full_name
# Out:
# 'Karina Tymoschenko'

# %%
print(full_name.upper())
print(full_name.lower())
print(len(full_name))
# Out:
# KARINA TYMOSCHENKO
# karina tymoschenko
# 18

# %%
print(f"Мене звати {full_name}, мені {age} років.")
# Out:
# Мене звати Karina Tymoschenko, мені 39 років.
