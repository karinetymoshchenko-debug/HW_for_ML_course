# %% [markdown]
# **List**

# %%
# Lists
temperatures=[22, 25, 19, 23, 26, 20, 21, 22]

# %%
temperatures
# Out:
# [22, 25, 19, 23, 26, 20, 21, 22]

# %%
print (temperatures[0]) #1st in the list
# Out:
# 22

# %%
print (temperatures[-1]) #last in te list
# Out:
# 22

# %%
temperatures.append(24) #запускала кілька разів

# %%
print(temperatures) #відповідно кілька разів додалося значення 24
# Out:
# [15, 25, 23, 26, 20, 21, 22, 24, 24, 24]

# %%
temperatures.remove(24)#виправлення списку - видалення зайвих знечень 24

# %%
print(temperatures)
# Out:
# [15, 25, 23, 26, 20, 21, 22, 24]

# %%
temperatures.remove(22) #remove element 22

# %%
print(temperatures)
# Out:
# [15, 25, 23, 26, 20, 21, 22, 24]

# %%
print(len(temperatures))
# Out:
# 8

# %%
print(sum(temperatures))
# Out:
# 176

# %%
print(max(temperatures))
# Out:
# 26

# %%
temperatures[0]=10 #new value

# %%
print(temperatures)
# Out:
# [10, 25, 23, 26, 20, 21, 22, 24]

# %% [markdown]
# **Dictionary**

# %%
person={
    "name":"Karina",
    "age":39,
    "city":"Dnipro",
    "position":"Business Analist",
    "vacation_status": False
}

# %%
person
# Out:
# {'name': 'Karina',
#  'age': 39,
#  'city': 'Dnipro',
#  'position': 'Business Analist',
#  'vacation_status': False}

# %%
print (person["name"])
# Out:
# Karina

# %%
person ["age"]=21 #update age value

# %%
print (person["age"]) #checking
# Out:
# 21

# %%
person #checking
# Out:
# {'name': 'Karina',
#  'age': 21,
#  'city': 'Dnipro',
#  'position': 'Business Analist',
#  'vacation_status': False}

# %%
person["hobby"]="programming" #new key hobby

# %%
person #checking
# Out:
# {'name': 'Karina',
#  'age': 21,
#  'city': 'Dnipro',
#  'position': 'Business Analist',
#  'vacation_status': False,
#  'hobby': 'programming'}

# %%
print(person.keys()) #keys
# Out:
# dict_keys(['name', 'age', 'city', 'position', 'vacation_status', 'hobby'])

# %%
print (person.values()) #values
# Out:
# dict_values(['Karina', 21, 'Dnipro', 'Business Analist', False, 'programming'])

# %%
print(person.items()) #key-value
# Out:
# dict_items([('name', 'Karina'), ('age', 21), ('city', 'Dnipro'), ('position', 'Business Analist'), ('vacation_status', False), ('hobby', 'programming')])
